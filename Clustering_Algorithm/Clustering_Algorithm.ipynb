# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import torch
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn import datasets
from utils.Clustering_Algorithm import Cluster

data = datasets.load_iris()

pd_data = pd.DataFrame(data.data,columns=data.feature_names) # type: ignore
pd_data['category'] = data.target # type:ignore

px.scatter_3d(pd_data,x='sepal length (cm)',y='sepal width (cm)',z='petal length (cm)',color='category',
              width=600,height=600)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = Cluster(pd_data.iloc[:,:-1],3,100,1e-6)

# %%
a.train(process=True)

# %%
a.process_plot()
